# %% [markdown]
# # Author - Saurabh Shinde

# %% [markdown]
# # Task 3 - Exploratory Data Analysis - Retail

# %% [markdown]
# # GRIP @ The Spark Foundation

# %% [markdown]
# Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’

# %% [markdown]
# Dataset link - https://bit.ly/3i4rbWl

# %% [markdown]
# Here i import some libraries which required for execution

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.head()                                       # here we can see first five rows form given dataset using head method
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape   # here we can see the number of rows and columns in dataset using shape function
# Out:
# (9994, 13)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.columns        # here we can see which columns are avialable in dataset
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info()             # here we can see the info about dataset like datatype non-null count etc. using info method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()      # here we can check in our dataset having any null values or not
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
print(df['Ship Mode'].unique())         # here we can see the unique values of ship mode column
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %%
print(df['Segment'].unique())          # here we can see the unique values of segment column
# Out:
# ['Consumer' 'Corporate' 'Home Office']

# %%
print(df['State'].unique())             # here we can see the unique values of state column
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
print(df['Country'].unique())             # here we can see the unique values of Country column
# Out:
# ['United States']

# %%
df.duplicated().sum()                     # here we can check for any values are duplicated or not
# Out:
# 17

# %%
df.describe()                         # describe function gives statistical info about dataset
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()                               # this function defines the relation between the columns
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='Reds')      # here we just visulize the relation of columns in graph format
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)                # By using pairplot we can see all the types of graph in one method

# %% [markdown]
# observations:
#     1] while increasing the discount sales are increased
#     2] while increasing discount the quantity is also incrased
#     3] sales incrementation positively impacted on profit
#     4] where postal code is high sales is less

# %%
sns.pairplot(data=df,hue='Profit')  # here we see the pairplot method apply for profit

# %%
sns.pairplot(data=df,hue='Sales')          # here we see the pairplot method apply for sales

# %%
df[['Postal Code','Sales','Quantity','Discount','Profit']].plot.box()# By using Box plot we can visulize the outliers of dataset
# Out:
# <AxesSubplot:>

# %%
df[['Postal Code']].plot.hist(title='Postal code Graph') # here we plot the histogram for postal code columns
# Out:
# <AxesSubplot:title={'center':'Postal code Graph'}, ylabel='Frequency'>

# %%
df[['Postal Code','Profit']].plot.hist(bins=15,title='postal code vs profit')
# here we plot the histogram for postal code and Profit columns respectively.
# Out:
# <AxesSubplot:title={'center':'postal code vs profit'}, ylabel='Frequency'>

# %%
df[['Sales','Quantity']].plot.hist(bins=15,title='Sales vs Quantity')
# here we plot the histogram for sales and quantity columns respectively.
# Out:
# <AxesSubplot:title={'center':'Sales vs Quantity'}, ylabel='Frequency'>

# %%
sns.countplot(df['Ship Mode']) # here we can see the count of all categories which are include in Ship mode feature
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
sns.countplot(df['Quantity']) # here we can see the count of all categories which are include in Quantity feature
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='count'>

# %%
sns.countplot(df['Segment'])   # here we can see the count of all categories which are include in Segment feature
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
df['Sub-Category'].value_counts() # By usnig value count method we can see all the values of categorical features
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(25,10))
df['Sub-Category'].value_counts().plot.pie(autopct='%1.1f%%') # here we plot pie chart for sub category column
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %%
state_group = df.groupby(['State'])[['Profit','Sales','Discount']].mean() 
# here we makes the states group by using group by function

# %%
df['State'].value_counts() # here we can see all the values of states.
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(35,15))
state_group['Sales'].plot.pie(autopct='%1.1f%%',startangle=90,shadow=True)
plt.title('sales analysis in State wise',fontsize=20)
# Out:
# Text(0.5, 1.0, 'sales analysis in State wise')

# %%
plt.figure(figsize=(15,15))
state_group['Profit'].plot.barh() # here we check profits for all states
# Out:
# <AxesSubplot:ylabel='State'>

# %%
state_group['Profit'].max() # by using max functin we can find max profit of state
# Out:
# 204.08893636363638

# %%
state_group['Profit'].min() # by using min functin we can find minimum profit of state
# Out:
# -36.18630405117275

# %%
plt.figure(figsize=(25,18))
state_group['Discount'].plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Discount'>

# %%
state_group['Discount'].max() # by using max functin we can find max discount of state
# Out:
# 0.390040650406503

# %%
state_group['Discount'].min() # by using min functin we can find minimum discount of state
# Out:
# 0.0

# %%
plt.figure(figsize=(50,10))
sns.countplot(x='State',data=df,order=df['State'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
df['Region'].value_counts().plot.pie(autopct='%1.1f%%')  # here we plot pie chart for region analysis
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df,x='Sales',y='Profit')
plt.legend()
plt.title('Sales vs Profit',fontsize=20)

# here we plot the line plot graph for sales vs pprofit
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Sales vs Profit')

# %%
segment_group = df.groupby(['Segment'])[['Profit','Sales','Discount']].mean()

# here i am make group of segment

# %%
print(segment_group)
# Out:
#                 Profit       Sales  Discount
# Segment
# Consumer     25.836873  223.733644  0.158141
# Corporate    30.456667  233.823300  0.158228
# Home Office  33.818664  240.972041  0.147128

# %%
plt.figure(figsize=(10,10))
segment_group['Profit'].plot.pie(autopct='%1.1f%%') # here  i am plot pie chart for analyse the profit in segment
# Out:
# <AxesSubplot:ylabel='Profit'>

# %%
plt.figure(figsize=(10,10))
segment_group['Sales'].plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
plt.figure(figsize=(10,7))
segment_group['Discount'].plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Discount'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## In this given Dataset we can see that the profit is increased while sales are increased,in some state having less sales with negative profit there should be focused for increase the profit and in home offices having more sales than other sector
